# %% [markdown]
# # Rscript title is not showing in the side pane

# %% [markdown]
# ## A PLOT
#
# Certainly! R, a powerful statistical programming language, offers versatile plotting capabilities. The plot() function is fundamental for creating graphs. It allows you to generate scatter plots, bar plots, box plots, time series plots, and more. You can customize axes labels, colors, line types, and titles to create informative visualizations

# %%
## make a plot
x = runif(100,1,10)
y = x ^2
plot(x,y,main="test")
# Out:
# Plot with title "test"
